# %%
import pandas as pd
import numpy as np
import os

# %%
filepath1 = os.path.join("Resources" ,"JC-201704-citibike-tripdata.csv")
filepath2 = os.path.join("Resources" ,"JC-201705-citibike-tripdata.csv")
filepath3 = os.path.join("Resources" ,"JC-201706-citibike-tripdata.csv")
filepath4 = os.path.join("Resources" ,"JC-201707-citibike-tripdata.csv")
filepath5 = os.path.join("Resources" ,"JC-201708 citibike-tripdata.csv")
filepath6 = os.path.join("Resources" ,"JC-201709-citibike-tripdata.csv")

jc_201704 = pd.read_csv(filepath1)
jc_201705 = pd.read_csv(filepath2)
jc_201706 = pd.read_csv(filepath3)
jc_201707 = pd.read_csv(filepath4)
jc_201708 = pd.read_csv(filepath5)
jc_201709 = pd.read_csv(filepath6)

# %%
jc_201706.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           499  2017-06-01 00:01:39  2017-06-01 00:09:59              3195
# 1           507  2017-06-01 00:06:39  2017-06-01 00:15:07              3211
# 2           768  2017-06-01 00:44:43  2017-06-01 00:57:31              3195
# 3           101  2017-06-01 01:12:55  2017-06-01 01:14:36              3185
# 4           265  2017-06-01 01:14:00  2017-06-01 01:18:25              3273
#
#   start station name  start station latitude  start station longitude  \
# 0            Sip Ave               40.730743               -74.063784
# 1         Newark Ave               40.721525               -74.046305
# 2            Sip Ave               40.730743               -74.063784
# 3          City Hall               40.717733               -74.043845
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id         end station name  end station latitude  \
# ...

# %%
jc_combined = pd.concat([jc_201704, jc_201705, jc_201706, jc_201707, jc_201708, jc_201709])
jc_combined.count()
# Out:
# tripduration               181376
# starttime                  181376
# stoptime                   181376
# start station id           181376
# start station name         181376
# start station latitude     181376
# start station longitude    181376
# end station id             181376
# end station name           181376
# end station latitude       181376
# end station longitude      181376
# bikeid                     181376
# usertype                   181376
# birth year                 166921
# gender                     181376
# dtype: int64

# %%
jc_combined.to_csv("JC Combined Bike.csv", index=False)
